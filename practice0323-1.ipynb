# %%
import json
hsinchu_river=open("新竹縣水質分析.json",encoding="utf8")
data=json.load(hsinchu_river)
type(data)
# Out:
# dict

# %%
data
# Out:
# {'標題': '新竹縣112年第一季河川水質監測報告',
#  '鳳山溪': [{'南華橋監測站': [{'採樣日期': '2023/2/21',
#      '水溫': '17.2',
#      'pH': '7.6',
#      '溶氧量': '8.1',
#      '大腸桿菌群': '1500',
#      '懸浮固體': '5.4',
#      '鎘': '<0.001',
#      '銅': '<0.001',
#      '鉛': '<0.003',
#      '錳': '0.017',
#      '鎳': '<0.003',
#      '銀': '<0.001',
#      '鋅': '0.02',
#      '六價鉻': '<0.003',
#      '汞': '<0.0003',
#      '硒': '<0.0002',
#      '總磷': '0.053',
#      '砷': '@0.0006',
#      '硝酸鹽氮': '0.47',
#      '亞硝酸鹽氮': '<0.001',
#      '氨氮': '0.08',
#      '生化需氧量': '<2',
#      '化學需氧量': '7',
#      '總有機碳': '2.1',
#      '氯鹽': '3.7'}],
#    '坪林大橋監測站': [{'採樣日期': '2023/2/21',
#      '水溫': '17.6',
#      'pH': '7',
#      '溶氧量': '8.5',
#      '大腸桿菌群': '1300',
#      '懸浮固體': '8.6',
#      '鎘': '<0.001',
#      '銅': '<0.001',
#      '鉛': '@0.009',
#      '錳': '0.038',
#      '鎳': '<0.003',
#      '銀': '<0.001',
#      '鋅': '0.052',
#      '六價鉻': '<0.003',
#      '汞': '<0.0003',
#      '硒': '<0.0002',
#      '總磷': '0.08',
# ...

# %%
data.keys()
# Out:
# dict_keys(['標題', '鳳山溪', '霄裡溪', '新豐溪'])

# %%
data.values()
# Out:
# dict_values(['新竹縣112年第一季河川水質監測報告', [{'南華橋監測站': [{'採樣日期': '2023/2/21', '水溫': '17.2', 'pH': '7.6', '溶氧量': '8.1', '大腸桿菌群': '1500', '懸浮固體': '5.4', '鎘': '<0.001', '銅': '<0.001', '鉛': '<0.003', '錳': '0.017', '鎳': '<0.003', '銀': '<0.001', '鋅': '0.02', '六價鉻': '<0.003', '汞': '<0.0003', '硒': '<0.0002', '總磷': '0.053', '砷': '@0.0006', '硝酸鹽氮': '0.47', '亞硝酸鹽氮': '<0.001', '氨氮': '0.08', '生化需氧量': '<2', '化學需氧量': '7', '總有機碳': '2.1', '氯鹽': '3.7'}], '坪林大橋監測站': [{'採樣日期': '2023/2/21', '水溫': '17.6', 'pH': '7', '溶氧量': '8.5', '大腸桿菌群': '1300', '懸浮固體': '8.6', '鎘': '<0.001', '銅': '<0.001', '鉛': '@0.009', '錳': '0.038', '鎳': '<0.003', '銀': '<0.001', '鋅': '0.052', '六價鉻': '<0.003', '汞': '<0.0003', '硒': '<0.0002', '總磷': '0.08', '砷': '0.0006', '硝酸鹽氮': '0.89', '亞硝酸鹽氮': '0.01', '氨氮': '0.1', '生化需氧量': '2.6', '化學需氧量': '8.4', '總有機碳': '2.3', '氯鹽': '19.5'}], '寶石橋監測站': [{'採樣日期': '2023/2/21', '水溫': '17.4', 'pH': '5.8', '溶氧量': '8.6', '大腸桿菌群': '2500', '懸浮固體': '12.1', '鎘': '<0.001', '銅': '<0.001', '鉛': '@0.009', '錳': '0.084', '鎳':
# ...

# %%
data["鳳山溪"]
# Out:
# [{'南華橋監測站': [{'採樣日期': '2023/2/21',
#     '水溫': '17.2',
#     'pH': '7.6',
#     '溶氧量': '8.1',
#     '大腸桿菌群': '1500',
#     '懸浮固體': '5.4',
#     '鎘': '<0.001',
#     '銅': '<0.001',
#     '鉛': '<0.003',
#     '錳': '0.017',
#     '鎳': '<0.003',
#     '銀': '<0.001',
#     '鋅': '0.02',
#     '六價鉻': '<0.003',
#     '汞': '<0.0003',
#     '硒': '<0.0002',
#     '總磷': '0.053',
#     '砷': '@0.0006',
#     '硝酸鹽氮': '0.47',
#     '亞硝酸鹽氮': '<0.001',
#     '氨氮': '0.08',
#     '生化需氧量': '<2',
#     '化學需氧量': '7',
#     '總有機碳': '2.1',
#     '氯鹽': '3.7'}],
#   '坪林大橋監測站': [{'採樣日期': '2023/2/21',
#     '水溫': '17.6',
#     'pH': '7',
#     '溶氧量': '8.5',
#     '大腸桿菌群': '1300',
#     '懸浮固體': '8.6',
#     '鎘': '<0.001',
#     '銅': '<0.001',
#     '鉛': '@0.009',
#     '錳': '0.038',
#     '鎳': '<0.003',
#     '銀': '<0.001',
#     '鋅': '0.052',
#     '六價鉻': '<0.003',
#     '汞': '<0.0003',
#     '硒': '<0.0002',
#     '總磷': '0.08',
#     '砷': '0.0006',
#     '硝酸鹽氮': '0.89',
#     '亞硝酸鹽氮': '0.01',
#     '氨氮': '0.1',
# ...

# %%
for n in data.items():
    print(n[1])
# Out:
# 新竹縣112年第一季河川水質監測報告
# ...

# %%
a = data.get('霄裡溪')
a
# Out:
# [{'照東橋監測站': [{'採樣日期': '2023/2/21',
#     '水溫': '18.6',
#     'pH': '5.7',
#     '溶氧量': '7.5',
#     '大腸桿菌群': '19000',
#     '懸浮固體': '31.3',
#     '鎘': '<0.001',
#     '銅': '@0.003',
#     '鉛': '<0.003',
#     '錳': '0.073',
#     '鎳': '<0.003',
#     '銀': '<0.001',
#     '鋅': '0.037',
#     '六價鉻': '<0.003',
#     '汞': '<0.0003',
#     '硒': '<0.0002',
#     '總磷': '0.979',
#     '砷': '0.0011',
#     '硝酸鹽氮': '2.48',
#     '亞硝酸鹽氮': '0.06',
#     '氨氮': '0.68',
#     '生化需氧量': '5',
#     '化學需氧量': '26.6',
#     '總有機碳': '5',
#     '氯鹽': '16.9'}],
#   '霄裡橋監測站': [{'採樣日期': '2023/2/21',
#     '水溫': '18.2',
#     'pH': '7',
#     '溶氧量': '8.1',
#     '大腸桿菌群': '8600',
#     '懸浮固體': '8.8',
#     '鎘': '<0.001',
#     '銅': '<0.001',
#     '鉛': '<0.003',
#     '錳': '0.126',
#     '鎳': '<0.003',
#     '銀': '<0.001',
#     '鋅': '0.007',
#     '六價鉻': '<0.003',
#     '汞': '<0.0003',
#     '硒': '<0.0002',
#     '總磷': '0.54',
#     '砷': '0.002',
#     '硝酸鹽氮': '2.23',
#     '亞硝酸鹽氮': '0.12',
#     '氨氮': '0.32',
# ...

# %%
b = data.get('新豐溪')
b
# Out:
# [{'信勢橋監測站': [{'採樣日期': '2023/2/22',
#     '水溫': '15.7',
#     'pH': '6.1',
#     '溶氧量': '6.2',
#     '大腸桿菌群': '170000',
#     '懸浮固體': '8.5',
#     '鎘': '<0.001',
#     '銅': '<0.001',
#     '鉛': '<0.003',
#     '錳': '0.092',
#     '鎳': '<0.003',
#     '銀': '<0.001',
#     '鋅': '0.02',
#     '六價鉻': '<0.003',
#     '汞': '<0.0003',
#     '硒': '<0.0002',
#     '總磷': '0.809',
#     '砷': '0.0011',
#     '硝酸鹽氮': '0.57',
#     '亞硝酸鹽氮': '0.1',
#     '氨氮': '7.48',
#     '生化需氧量': '4.4',
#     '化學需氧量': '24.6',
#     '總有機碳': '9.6',
#     '氯鹽': '40.9'}],
#   '振興橋監測站': [{'採樣日期': '2023/2/22',
#     '水溫': '14.7',
#     'pH': '5.9',
#     '溶氧量': '7.5',
#     '大腸桿菌群': '6100',
#     '懸浮固體': '24.9',
#     '鎘': '<0.001',
#     '銅': '0.017',
#     '鉛': '@0.009',
#     '錳': '0.189',
#     '鎳': '0.009',
#     '銀': '<0.001',
#     '鋅': '0.044',
#     '六價鉻': '<0.003',
#     '汞': '<0.0003',
#     '硒': '<0.0002',
#     '總磷': '0.69',
#     '砷': '0.0012',
#     '硝酸鹽氮': '2.09',
#     '亞硝酸鹽氮': '0.21',
# ...

# %%
#json檔案內容
{
  "標題": "新竹縣112年第一季河川水質監測報告",
  "鳳山溪": [
    {
      "南華橋監測站": [
        {
          "採樣日期": "2023/2/21",
          "水溫": "17.2",
          "pH": "7.6",
          "溶氧量": "8.1",
          "大腸桿菌群": "1500",
          "懸浮固體": "5.4",
          "鎘": "<0.001",
          "銅": "<0.001",
          "鉛": "<0.003",
          "錳": "0.017",
          "鎳": "<0.003",
          "銀": "<0.001",
          "鋅": "0.02",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.053",
          "砷": "@0.0006",
          "硝酸鹽氮": "0.47",
          "亞硝酸鹽氮": "<0.001",
          "氨氮": "0.08",
          "生化需氧量": "<2",
          "化學需氧量": "7",
          "總有機碳": "2.1",
          "氯鹽": "3.7"
        }
      ],
      "坪林大橋監測站": [
        {
          "採樣日期": "2023/2/21",
          "水溫": "17.6",
          "pH": "7",
          "溶氧量": "8.5",
          "大腸桿菌群": "1300",
          "懸浮固體": "8.6",
          "鎘": "<0.001",
          "銅": "<0.001",
          "鉛": "@0.009",
          "錳": "0.038",
          "鎳": "<0.003",
          "銀": "<0.001",
          "鋅": "0.052",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.08",
          "砷": "0.0006",
          "硝酸鹽氮": "0.89",
          "亞硝酸鹽氮": "0.01",
          "氨氮": "0.1",
          "生化需氧量": "2.6",
          "化學需氧量": "8.4",
          "總有機碳": "2.3",
          "氯鹽": "19.5"
        }
      ],
      "寶石橋監測站": [
        {
          "採樣日期": "2023/2/21",
          "水溫": "17.4",
          "pH": "5.8",
          "溶氧量": "8.6",
          "大腸桿菌群": "2500",
          "懸浮固體": "12.1",
          "鎘": "<0.001",
          "銅": "<0.001",
          "鉛": "@0.009",
          "錳": "0.084",
          "鎳": "<0.003",
          "銀": "<0.001",
          "鋅": "0.033",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.236",
          "砷": "0.0011",
          "硝酸鹽氮": "1.01",
          "亞硝酸鹽氮": "0.04",
          "氨氮": "0.28",
          "生化需氧量": "3.2",
          "化學需氧量": "12.9",
          "總有機碳": "3.9",
          "氯鹽": "20.5"
        }
      ]
    }
  ],
  "霄裡溪": [
    {
      "照東橋監測站": [
        {
          "採樣日期": "2023/2/21",
          "水溫": "18.6",
          "pH": "5.7",
          "溶氧量": "7.5",
          "大腸桿菌群": "19000",
          "懸浮固體": "31.3",
          "鎘": "<0.001",
          "銅": "@0.003",
          "鉛": "<0.003",
          "錳": "0.073",
          "鎳": "<0.003",
          "銀": "<0.001",
          "鋅": "0.037",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.979",
          "砷": "0.0011",
          "硝酸鹽氮": "2.48",
          "亞硝酸鹽氮": "0.06",
          "氨氮": "0.68",
          "生化需氧量": "5",
          "化學需氧量": "26.6",
          "總有機碳": "5",
          "氯鹽": "16.9"
        }
      ],
      "霄裡橋監測站": [
        {
          "採樣日期": "2023/2/21",
          "水溫": "18.2",
          "pH": "7",
          "溶氧量": "8.1",
          "大腸桿菌群": "8600",
          "懸浮固體": "8.8",
          "鎘": "<0.001",
          "銅": "<0.001",
          "鉛": "<0.003",
          "錳": "0.126",
          "鎳": "<0.003",
          "銀": "<0.001",
          "鋅": "0.007",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.54",
          "砷": "0.002",
          "硝酸鹽氮": "2.23",
          "亞硝酸鹽氮": "0.12",
          "氨氮": "0.32",
          "生化需氧量": "5.4",
          "化學需氧量": "15.5",
          "總有機碳": "5.2",
          "氯鹽": "22.9"
        }
      ]
    }
  ],
  "新豐溪": [
    {
      "信勢橋監測站": [
        {
          "採樣日期": "2023/2/22",
          "水溫": "15.7",
          "pH": "6.1",
          "溶氧量": "6.2",
          "大腸桿菌群": "170000",
          "懸浮固體": "8.5",
          "鎘": "<0.001",
          "銅": "<0.001",
          "鉛": "<0.003",
          "錳": "0.092",
          "鎳": "<0.003",
          "銀": "<0.001",
          "鋅": "0.02",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.809",
          "砷": "0.0011",
          "硝酸鹽氮": "0.57",
          "亞硝酸鹽氮": "0.1",
          "氨氮": "7.48",
          "生化需氧量": "4.4",
          "化學需氧量": "24.6",
          "總有機碳": "9.6",
          "氯鹽": "40.9"
        }
      ],
      "振興橋監測站": [
        {
          "採樣日期": "2023/2/22",
          "水溫": "14.7",
          "pH": "5.9",
          "溶氧量": "7.5",
          "大腸桿菌群": "6100",
          "懸浮固體": "24.9",
          "鎘": "<0.001",
          "銅": "0.017",
          "鉛": "@0.009",
          "錳": "0.189",
          "鎳": "0.009",
          "銀": "<0.001",
          "鋅": "0.044",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.69",
          "砷": "0.0012",
          "硝酸鹽氮": "2.09",
          "亞硝酸鹽氮": "0.21",
          "氨氮": "1.06",
          "生化需氧量": "3.5",
          "化學需氧量": "22.4",
          "總有機碳": "9",
          "氯鹽": "91.2"
        }
      ],
      "中崎橋監測站": [
        {
          "採樣日期": "2023/2/22",
          "水溫": "20.2",
          "pH": "7.3",
          "溶氧量": "6.4",
          "大腸桿菌群": "1900",
          "懸浮固體": "12.8",
          "鎘": "<0.001",
          "銅": "0.159",
          "鉛": "@0.009",
          "錳": "0.565",
          "鎳": "0.09",
          "銀": "<0.001",
          "鋅": "0.125",
          "六價鉻": "<0.003",
          "汞": "<0.0003",
          "硒": "<0.0002",
          "總磷": "0.432",
          "砷": "@0.0006",
          "硝酸鹽氮": "0.17",
          "亞硝酸鹽氮": "0.1",
          "氨氮": "2.6",
          "生化需氧量": "4.6",
          "化學需氧量": "17.3",
          "總有機碳": "7.6",
          "氯鹽": "399"
        }
      ]
    }
  ]
}
# Out:
# {'標題': '新竹縣112年第一季河川水質監測報告',
#  '鳳山溪': [{'南華橋監測站': [{'採樣日期': '2023/2/21',
#      '水溫': '17.2',
#      'pH': '7.6',
#      '溶氧量': '8.1',
#      '大腸桿菌群': '1500',
#      '懸浮固體': '5.4',
#      '鎘': '<0.001',
#      '銅': '<0.001',
#      '鉛': '<0.003',
#      '錳': '0.017',
#      '鎳': '<0.003',
#      '銀': '<0.001',
#      '鋅': '0.02',
#      '六價鉻': '<0.003',
#      '汞': '<0.0003',
#      '硒': '<0.0002',
#      '總磷': '0.053',
#      '砷': '@0.0006',
#      '硝酸鹽氮': '0.47',
#      '亞硝酸鹽氮': '<0.001',
#      '氨氮': '0.08',
#      '生化需氧量': '<2',
#      '化學需氧量': '7',
#      '總有機碳': '2.1',
#      '氯鹽': '3.7'}],
#    '坪林大橋監測站': [{'採樣日期': '2023/2/21',
#      '水溫': '17.6',
#      'pH': '7',
#      '溶氧量': '8.5',
#      '大腸桿菌群': '1300',
#      '懸浮固體': '8.6',
#      '鎘': '<0.001',
#      '銅': '<0.001',
#      '鉛': '@0.009',
#      '錳': '0.038',
#      '鎳': '<0.003',
#      '銀': '<0.001',
#      '鋅': '0.052',
#      '六價鉻': '<0.003',
#      '汞': '<0.0003',
#      '硒': '<0.0002',
#      '總磷': '0.08',
# ...

# %%
open("jsoncrack.com.png")
# Out:
# <_io.TextIOWrapper name='jsoncrack.com.png' mode='r' encoding='cp950'>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("jsoncrack.com.png")
plt.imshow(img)
plt.show()
