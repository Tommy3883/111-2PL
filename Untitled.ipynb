# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
}

r = requests.get('https://ani.gamer.com.tw/', headers=headers)
if r.status_code == 200:
    print(f'請求成功：{r.status_code}')
else:
    print(f'請求失敗：{r.status_code}')
# Out:
# 請求成功：200

# %%
##抓到35組動畫元素
soup = BeautifulSoup(r.text, 'html.parser')
newanime_item = soup.select_one('.timeline-ver > .newanime-block')
anime_items = newanime_item.select('.newanime-date-area:not(.premium-block)')
anime_items
# Out:
# [<div class="newanime-date-area new-count-1 fadeIn" data-animesn="113259" data-date-code="1">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33335">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">02:25</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/39/976c338fc90732c44918cc5e391l8zj5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125076, 113259, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">江戶前精靈</p>
#  <p class="anime-name_for-marquee">江戶前精靈</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>6.4萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/15 (六)
#  </span>
#  <span class="anime-date-info anime-date-info-block-rectangle">
#  <svg class="anime-date_svg-not-active" viewbox="0 0 82 28">
#  <title>svg_not_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_not-active">
#  <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/15 (六)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-1 fadeIn" data-animesn="113242" data-date-code="1">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33331">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">01:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/31/faa008efadd348a6d34a2317b81l9ir5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第15集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125428, 113242, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">小鳥之翼 第二季</p>
#  <p class="anime-name_for-marquee">小鳥之翼 第二季</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>1萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/15 (六)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-1 fadeIn" data-animesn="113252" data-date-code="1">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33329">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">00:30</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/30/52789d0139902094e529a3e3121l9iq5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125527, 113252, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">肌肉魔法使-MASHLE-</p>
#  <p class="anime-name_for-marquee">肌肉魔法使-MASHLE-</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>12.6萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/15 (六)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113249" data-date-code="2">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33317">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">01:40</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/63/c83f86047eb7d27562c35cf2701l85n5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第1集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(126302, 113249, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">國王排名 勇氣的寶箱</p>
#  <p class="anime-name_for-marquee">國王排名 勇氣的寶箱</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>1.9萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/14 (五)
#  </span>
#  <span class="anime-date-info anime-date-info-block-rectangle">
#  <svg class="anime-date_svg-not-active" viewbox="0 0 82 28">
#  <title>svg_not_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_not-active">
#  <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/14 (五)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113241" data-date-code="2">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33327">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">01:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/37/59d7e25f2ef6bcba67566cdc4b1l8it5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(128843, 113241, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">勇者死了！</p>
#  <p class="anime-name_for-marquee">勇者死了！</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>15.5萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/14 (五)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-2 fadeIn" data-animesn="113261" data-date-code="2">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33324">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">00:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/10/a5efe5a72214bb84f1ba73ac8c1l8nm5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(128902, 113261, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">Opus.COLORs 色彩高校星</p>
#  <p class="anime-name_for-marquee">Opus.COLORs 色彩高校星</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>6308</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/14 (五)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113239" data-date-code="3">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33320">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">22:30</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/16/2dca6c0bc147b76e66cabd586f1l8qk5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(128544, 113239, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">百合是我的工作！</p>
#  <p class="anime-name_for-marquee">百合是我的工作！</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>4.1萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/13 (四)
#  </span>
#  <span class="anime-date-info anime-date-info-block-rectangle">
#  <svg class="anime-date_svg-not-active" viewbox="0 0 82 28">
#  <title>svg_not_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_not-active">
#  <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/13 (四)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113251" data-date-code="3">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33318">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">22:30</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/04/ec2c36c839dcbd4546b83e7cb91l7yg5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125702, 113251, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">Dr. STONE 新石紀 第三季</p>
#  <p class="anime-name_for-marquee">Dr. STONE 新石紀 第三季</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>11.7萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/13 (四)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113258" data-date-code="3">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33322">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">22:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/84/2ad8a973415746d9b8d0b392df1l90s5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(126945, 113258, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">魔法使的新娘 第二季</p>
#  <p class="anime-name_for-marquee">魔法使的新娘 第二季</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>7.2萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/13 (四)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-3 fadeIn" data-animesn="113238" data-date-code="3">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33315">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">00:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/91/b3dd340e60a307bb08b4e6b09d1l7y35.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(129014, 113238, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">為美好的世界獻上爆焰！</p>
#  <p class="anime-name_for-marquee">為美好的世界獻上爆焰！</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>30.8萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04
JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(122447, 113257, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">機戰少女 Alice Expansion</p>
#  <p class="anime-name_for-marquee">機戰少女 Alice Expansion</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>2.8萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/10 (一)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-6 newanime-content-hide fadeIn" data-animesn="113254" data-date-code="6">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33295">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">01:05</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/26/cb4f0d12be7602ccb9e4fd58081l6cq5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第1集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(122787, 113254, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">鬼滅之刃 刀匠村篇</p>
#  <p class="anime-name_for-marquee">鬼滅之刃 刀匠村篇</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>31.9萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/10 (一)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-6 newanime-content-hide fadeIn" data-animesn="113172" data-date-code="6">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33229">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">00:30</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/29/b2d4a53b197239fc25145b6a6c1l6ct5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第18集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125724, 113172, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">我與機器子</p>
#  <p class="anime-name_for-marquee">我與機器子</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>71.7萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/10 (一)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-7 newanime-content-hide fadeIn" data-animesn="113253" data-date-code="7">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33294">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">23:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/07/23a782ce153a27f81001b9f4621l5pz5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
# ...
#  <div class="anime-name">
#  <p class="">鄰人似銀河</p>
#  <p class="anime-name_for-marquee">鄰人似銀河</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>3.7萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/09 (日)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-7 newanime-content-hide fadeIn" data-animesn="113244" data-date-code="7">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33290">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">01:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/53/c0f2340eb4009ffbc7641bdb421l6555.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(127607, 113244, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">和山田談場 Lv999 的戀愛</p>
#  <p class="anime-name_for-marquee">和山田談場 Lv999 的戀愛</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>19.9萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/09 (日)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-7 newanime-content-hide fadeIn" data-animesn="113197" data-date-code="7">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33223">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">00:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/28/8a94b76730924e0eaa7d5e76381l6cs5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第11集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(127617, 113197, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">UniteUp! 眾星齊聚</p>
#  <p class="anime-name_for-marquee">UniteUp! 眾星齊聚</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>8萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/09 (日)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-8 newanime-content-hide fadeIn" data-animesn="113243" data-date-code="8">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33289">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">18:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/27/c8cadbfa4c567acafd3b08b9551l6cr5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第2集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(129165, 113243, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">MIX 第二季 ~第二個夏天，邁向晴空~</p>
#  <p class="anime-name_for-marquee">MIX 第二季 ~第二個夏天，邁向晴空~</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>1.3萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/08 (六)
#  </span>
#  <span class="anime-date-info anime-date-info-block-rectangle">
#  <svg class="anime-date_svg-not-active" viewbox="0 0 82 28">
#  <title>svg_not_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_not-active">
#  <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/08 (六)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-9 newanime-content-hide fadeIn" data-animesn="113186" data-date-code="9">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33225">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">20:30</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/39/5b347c4979098a4e7cd7f22d791l4if5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第12集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(127627, 113186, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">魔術士歐菲 流浪之旅 阿邦拉馬篇</p>
#  <p class="anime-name_for-marquee">魔術士歐菲 流浪之旅 阿邦拉馬篇</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>5.5萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/05 (三)
#  </span>
#  <span class="anime-date-info anime-date-info-block-rectangle">
#  <svg class="anime-date_svg-not-active" viewbox="0 0 82 28">
#  <title>svg_not_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_not-active">
#  <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/05 (三)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-10 newanime-content-hide fadeIn" data-animesn="113256" data-date-code="10">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33280">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">04:20</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/11/71a1b80ccc94d2f2d0cb2b0ea31l4c35.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第4集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125624, 113256, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">輝夜姬想讓人告白－永不結束的初吻－</p>
#  <p class="anime-name_for-marquee">輝夜姬想讓人告白－永不結束的初吻－</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>48.2萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/03 (一)
#  </span>
#  <span class="anime-date-info anime-date-info-block-rectangle">
#  <svg class="anime-date_svg-not-active" viewbox="0 0 82 28">
#  <title>svg_not_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_not-active">
#  <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/03 (一)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-10 newanime-content-hide fadeIn" data-animesn="113256" data-date-code="10">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33279">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">04:20</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/10/fa7d1130a9ff62d65abeae80a21l4c25.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  <img alt="pic-tv" src="https://i2.bahamut.com.tw/anime/pic-tv.svg"/><p>第3集</p>
#  </div>
#  <div class="anime-label-block">
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(125624, 113256, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">輝夜姬想讓人告白－永不結束的初吻－</p>
#  <p class="anime-name_for-marquee">輝夜姬想讓人告白－永不結束的初吻－</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>48.2萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 82 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L64,0 A8,8 0 0 1 70.8,2.8 L79.2,11.2 A4,4 0 0 1 79.2,16.8 L70.8,25.2 A8,8 0 0 1 64,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  04/03 (一)
#  </span>
#  </div>,
#  <div class="newanime-date-area new-count-11 newanime-content-hide new-count-media fadeIn" data-animesn="113231" data-date-code="11">
#  <div class="anime-content-block">
#  <div class="date-block">
#  <div class="pic-continue">
#  <img alt="icon-continue" src="https://i2.bahamut.com.tw/anime/pic-continue.svg"/>
#  </div>
#  <div class="date-block-border"></div>
#  </div>
#  <div class="anime-block">
#  <a class="anime-card-block" data-gtm="本季新番卡片" href="animeVideo.php?sn=33122">
#  <div class="anime-pic-block">
#  <div class="anime-hours-block">
#  <img alt="clock_img" class="anime-clock-img" src="https://i2.bahamut.com.tw/anime/pic_time_icon.svg"/>
#  <span class="anime-hours">23:00</span>
#  </div>
#  <div class="anime-blocker">
#  <img alt="anime_pic" class="lazyload" data-src="https://p2.bahamut.com.tw/B/2KU/13/5b257cf6c24c1bfaef704e41a71kv2t5.JPG"/>
#  </div>
#  <div class="line-gradient"></div>
#  <div class="anime-detail-info-block">
#  <div class="anime-episode">
#  </div>
#  <div class="anime-label-block">
#  <span class="label-edition color-OVA">電影</span><span class="label-edition color-paid">付費會員</span>
#  </div>
#  </div>
#  <div class="btn-card-block btn-favorite btn-not-active" onclick='animefun.toggleGather(119767, 113231, $(this), "btn-is-active"); return false;'></div>
#  </div>
#  <div class="anime-name-block">
#  <div class="anime-name">
#  <p class="">關於我轉生變成史萊姆這檔事劇場版 紅蓮之絆篇</p>
#  <p class="anime-name_for-marquee">關於我轉生變成史萊姆這檔事劇場版 紅蓮之絆篇</p>
#  </div>
#  <div class="anime-watch-number">
#  <i class="pic-eye-style material-icons">remove_red_eye</i>
#  <p>8.1萬</p>
#  </div>
#  </div>
#  </a>
#  </div>
#  </div>
#  <span class="anime-date-info anime-date-info-block-arrow">
#  <svg class="anime-date_svg-is-active" viewbox="0 0 68 28">
#  <title>svg_is_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_is-active">
#  <path d="M4,0 L50,0 A8,8 0 0 1 54.8,2.8 L64.2,11.2 A4,4 0 0 1 64.2,16.8 L56.8,25.2 A8,8 0 0 1 50,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  其他
#  </span>
#  <span class="anime-date-info anime-date-info-block-rectangle">
#  <svg class="anime-date_svg-not-active" viewbox="0 0 82 28">
#  <title>svg_not_active</title>
#  <g fill="none" fill-rule="evenodd">
#  <g class="anime-date-info_not-active">
#  <path d="M4,0 L78,0 A4,4 0 0 1 82,4 L82,24 A4,4 0 0 1 78,28 L4,28 A4,4 0 0 1 0,24 L0,4 A4,4 0 0 1 4,0 Z"></path>
#  </g>
#  </g>
#  </svg>
#
#  其他
#  </span>
#  </div>]

# %%
# 依序針對每個動畫區塊擷取資料#抓取 "動畫名稱"、"觀看人數"、"動畫集數"、"觀看連結"
for anime_item in anime_items:
    anime_name = anime_item.select_one('.anime-name > p').text.strip()
    print(anime_name)
    anime_watch_number = anime_item.select_one('.anime-watch-number > p').text.strip()
    print(anime_watch_number)
    anime_episode = anime_item.select_one('.anime-episode').text.strip()
    print(anime_episode)
    anime_href = anime_item.select_one('a.anime-card-block').get('href')
    print('https://ani.gamer.com.tw/'+anime_href)

print('----------')
# Out:
# 江戶前精靈
# 6.4萬
# 第2集
# https://ani.gamer.com.tw/animeVideo.php?sn=