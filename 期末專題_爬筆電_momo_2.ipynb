# %%
import requests 
import json
import csv
import time
from time import sleep
import pandas as pd
import re
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# 設定 User-Agent

headers = {
    'cookie': 'over18=1', 
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100008&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

if response.status_code == 200:
    print(f'請求成功：{response.status_code}')
else:
    print(f'請求失敗：{response.status_code}')
# Out:
# 請求成功：200

# %%
#ASUS
# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'w', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['網址'])  # 寫入表頭

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#ACER
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100003&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#聯想
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100160&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#Thinkpad
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100179&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#HP
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100013&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#微軟
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100759&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#微星
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100239&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#戴爾
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100202&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#技嘉
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100446&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#Dynabook
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100140&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#Avita
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100877&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#LG
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300101178&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#富士通
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100274&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#CJscope
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100636&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#razer
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100099&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#華微
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100295&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料

# %%
#創作者
# 發送 GET 請求取得文章內容
url = "https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=4300100074&sourcePageType=4"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# 找到 bt_2_layout_b1 內容
content = soup.select_one('#bt_2_layout_b1')

# 找到符合條件的連結
target_links = content.select('#bt_2_112_1_L_1 > a[href^="/goods/GoodsDetail.jsp"]')
time.sleep(5)

# 建立 CSV 檔案並寫入連結資料
with open('laptop_all_links.csv', 'a', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)

    # 遍歷連結並寫入 CSV 檔案
    for target_link in target_links:
        href = target_link['href']
        full_link = urljoin('https://www.momoshop.com.tw', href)
        writer.writerow([full_link])  # 寫入一行資料
